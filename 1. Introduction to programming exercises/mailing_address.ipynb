# %%
print("Jaydeep Kulkarni")
print("Flat No. 13, Avish Apartments")
print("Rambaug Colony, Kothrud")
print("Pune - 411038")
print("Maharashtra")
print("India")
# Out:
# Jaydeep Kulkarni
# Flat No. 13, Avish Apartments
# Rambaug Colony, Kothrud
# Pune - 411038
# Maharashtra
# India
