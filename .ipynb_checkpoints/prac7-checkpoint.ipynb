# %%
import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import math
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 from nltk.stem import PorterStemmer, WordNetLemmatizer
#       6 import math
# ----> 7 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Jaydeep
# [nltk_data]     Kulkarni\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to C:\Users\Jaydeep
# [nltk_data]     Kulkarni\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to C:\Users\Jaydeep
# [nltk_data]     Kulkarni\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to C:\Users\Jaydeep
# [nltk_data]     Kulkarni\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Jaydeep Kulkarni\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Jaydeep Kulkarni\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
text = "Tokenization is the first step in text analytics. The process of breaking down a text paragraph into smaller chunks such as words or sentences is called Tokenization."

# %%
print(sent_tokenize(text))
# Out:
# ['Tokenization is the first step in text analytics.', 'The process of breaking down a text paragraph into smaller chunks such as words or sentences is called Tokenization.']

# %%
print(word_tokenize(text))
# Out:
# ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', '.', 'The', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'Tokenization', '.']

# %%
stop_words = set(stopwords.words("english"))

# %%
text2 = "How to remove stop words with NLTK library in Python?"
text2 = re.sub('[^a-zA-Z]', ' ', text2)
tokens = word_tokenize(text2.lower())

# %%
filtered_text = [w for w in tokens if w not in stop_words]

# %%
print("\nAfter Stop Word Removal:")
print("Tokens:  ", tokens)
print("Filtered:", filtered_text)
# Out:
# After Stop Word Removal:
# Tokens:   ['how', 'to', 'remove', 'stop', 'words', 'with', 'nltk', 'library', 'in', 'python']
# Filtered: ['remove', 'stop', 'words', 'nltk', 'library', 'python']

# %%
ps = PorterStemmer()
e_words = ["wait", "waiting", "waited", "waits"]

# %%
print("\nStemming:")
for w in e_words:
    print(f"{w} → {ps.stem(w)}")
# Out:
# Stemming:
# wait → wait
# waiting → wait
# waited → wait
# waits → wait

# %%
wl = WordNetLemmatizer()
text3 = "studies studying cries cry"
tokens3 = word_tokenize(text3)

# %%
print("\nLemmatization:")
for w in tokens3:
    print(f"Lemma for {w} is {wl.lemmatize(w)}")
# Out:
# Lemmatization:
# Lemma for studies is study
# Lemma for studying is studying
# Lemma for cries is cry
# Lemma for cry is cry

# %%
print("\nStemming vs Lemmatization:")
for w in tokens3:
    print(f"{w:15} | Stem: {ps.stem(w):10} | Lemma: {wl.lemmatize(w)}")
# Out:
# Stemming vs Lemmatization:
# studies         | Stem: studi      | Lemma: study
# studying        | Stem: studi      | Lemma: studying
# cries           | Stem: cri        | Lemma: cry
# cry             | Stem: cri        | Lemma: cry

# %%
data = "The pink sweater fit her perfectly"
words = word_tokenize(data)

# %%
print("\nPOS Tagging:")
for word in words:
    print(nltk.pos_tag([word]))
# Out:
# POS Tagging:
# [('The', 'DT')]
# [('pink', 'NN')]
# [('sweater', 'NN')]
# [('fit', 'NN')]
# [('her', 'PRP$')]
# [('perfectly', 'RB')]

# %%
import sys
print(sys.executable)
# Out:
# c:\Program Files\Python312\python.exe

# %%
import sys
# !{sys.executable} -m pip install nltk
# Out:
# 'c:\Program' is not recognized as an internal or external command,
# operable program or batch file.
